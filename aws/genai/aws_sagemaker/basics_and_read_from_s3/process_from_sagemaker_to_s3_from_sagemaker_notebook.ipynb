# %%
import pandas as pd
import boto3
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::724512711323:role/SageMakerExecutionRole-HelloWorld

# %%
conn= boto3.client('s3')

# %%
bucket='my-sagemaker-hello-world'

# %%
content=conn.list_objects(Bucket=bucket)["Contents"]

# %%
content
# Out:
# [{'Key': 'code/',
#   'LastModified': datetime.datetime(2026, 2, 1, 10, 11, 59, tzinfo=tzlocal()),
#   'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#   'ChecksumAlgorithm': ['CRC64NVME'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 0,
#   'StorageClass': 'STANDARD',
#   'Owner': {'ID': '5f09548dc9a782bdcd7fda3070422e79c3beec974dffe2d0530abb69b9d2f6a6'}},
#  {'Key': 'code/hello_world.py',
#   'LastModified': datetime.datetime(2026, 2, 1, 10, 12, 21, tzinfo=tzlocal()),
#   'ETag': '"fcc1e2d0f21e883a5d0ed7f0d95367c7"',
#   'ChecksumAlgorithm': ['CRC64NVME'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 411,
#   'StorageClass': 'STANDARD',
#   'Owner': {'ID': '5f09548dc9a782bdcd7fda3070422e79c3beec974dffe2d0530abb69b9d2f6a6'}},
#  {'Key': 'household2.csv',
#   'LastModified': datetime.datetime(2026, 2, 1, 11, 22, 26, tzinfo=tzlocal()),
#   'ETag': '"80df995998be4e68e613448a7579b57f"',
#   'ChecksumAlgorithm': ['CRC64NVME'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 212462,
# ...

# %%
for data in content:
    print(data['Key'])
# Out:
# code/
# code/hello_world.py
# household2.csv
# input/
# input/input.txt
# output/
# output/output.txt

# %%
dataset='household2.csv'

# %%
df=pd.read_csv(f's3://{bucket}/{dataset}')

# %%
df
# Out:
#           Sales Person    Country              Product        Date  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022
# 1          Van Tuxwell      India        85% Dark Bars  01/08/2022
# 2         Gigi Bohling      India  Peanut Butter Cubes  07/07/2022
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022
# ...                ...        ...                  ...         ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims  17/05/2024
# 3278    Jehu Rudeforth        USA           White Choc  07/06/2024
# 3279      Ches Bonnell     Canada  Organic Choco Syrup  26/07/2024
# 3280    Dotty Strutley      India              Eclairs  28/07/2024
# 3281  Karlen McCaffrey      India       70% Dark Bites  23/05/2024
#
#           Amount  Boxes Shipped
# 0      $5,320.00            180
# 1      $7,896.00             94
# 2      $4,501.00             91
# ...
